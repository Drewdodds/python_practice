# %% [markdown]
# Resource vid: https://www.youtube.com/watch?v=x0Uguu7gqgk&t=5s
# In this lesson we will revisit line plots like the first vid but this time we are going to add to that line by adding in fills.
#
# They can give us some usuable fields depending on how we use them. For example, we can give conditional fills that will show us what areas of our line plot that fall above or below a certian threshold.

# %%
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('filling_line_charts_data_sample.csv')
ages = data['Age']
dev_salaries = data['All_Devs']
py_salaries = data['Python']
js_salaries = data['JavaScript']

plt.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

plt.plot(ages, py_salaries, label='Python')

# overall_median = 57287

plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()

# %% [markdown]
# This is a normal plot with out fill. Now let's fill it.

# %%
plt.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

plt.plot(ages, py_salaries, label='Python')

overall_median = 57287 # instead of using 0 as the fill in value let's use this

plt.fill_between(ages, py_salaries, overall_median, 
                 where=(py_salaries> overall_median),
                 interpolate=True, 
                 alpha=0.25) # this fill the area above where the python salaries meet the median salary threshold and above

plt.fill_between(ages, py_salaries, overall_median, 
                 where=(py_salaries <= overall_median),
                 interpolate=True, color='red', 
                 alpha=0.25) # this will fill the opposte. Where the python salaries have not yet met the median salary value

# alpha is how much we can see through the fill
plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()

# %% [markdown]
# What if we wanted to do a fill in inbetween the python salaries and the overall dev salaries?

# %%
plt.plot(ages, dev_salaries, color='#444444',
         linestyle='--', label='All Devs')

plt.plot(ages, py_salaries, label='Python')


plt.fill_between(ages, py_salaries, dev_salaries, 
                 where=(py_salaries> dev_salaries),
                 interpolate=True, 
                 alpha=0.25, label='Above Avg') 

plt.fill_between(ages, py_salaries, dev_salaries, 
                 where=(py_salaries <= dev_salaries),
                 interpolate=True, color='red', 
                 alpha=0.25, label='Below Avg') 

# alpha is how much we can see through the fill
plt.legend()

plt.title('Median Salary (USD) by Age')
plt.xlabel('Ages')
plt.ylabel('Median Salary (USD)')

plt.tight_layout()

plt.show()

# %% [markdown]
# This is really cool.
